# %% [markdown]
# # Exploring Data

# %%
# importing libraries
import pandas as pd 
import numpy as np
# Out:
# /Users/0xnrous/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
data = pd.read_csv("./rent_apartments.csv")
data.sample(10)
# Out:
#                                             address  area  constraction_year  \
# 219          1016 GC Amsterdam (Leidsegracht Noord)  54.0               1906
# 900                  1056 JL Amsterdam (Trompbuurt)  52.0               1950
# 966    1091 TT Amsterdam (Weesperzijde Midden/Zuid)  32.0               1907
# 1619             1067 DB Amsterdam (Eendrachtspark)  80.0               1993
# 920             1078 TT Amsterdam (IJselbuurt Oost)  70.0               1930
# 1154                1074 CJ Amsterdam (Hemonybuurt)  48.0               2013
# 963             1091 CD Amsterdam (Swammerdambuurt)  72.0               1893
# 584   1082 CV Amsterdam (Buitenveldert Midden Zuid)  67.0               2020
# 1538      1051 GC Amsterdam (Fannius Scholtenbuurt)  45.0               1898
# 1660              1066 XT Amsterdam (Staalmanbuurt)  62.0               2010
#
#       rooms  bedrooms  bathrooms balcony storage parking furnished garage  \
# ...
